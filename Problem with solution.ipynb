# %%
#Problem_01
#The input file will contain 2 integer numbers. Print even and odd numbers between them.

numbers=list(map(int,input("Enter two numbers:").split()))
print(f"Your range is {numbers[0]} to {numbers[1]}")

num1=numbers[0]
num2=numbers[1]

print("Even Numbers:")
for i in range(num1,num2):
    if i%2 == 0:
        print(i,end=" ")
        
print("\nOdd  Numbers:")
for n in range(num1,num2):
    if n%2 != 0:
        print(n,end=" ")
# Out:
# Enter two numbers: 5 10
# Your range is 5 to 10
# Even Numbers:
# 6 8
# Odd  Numbers:
# 5 7 9

# %%
#Problem_02
#The input contains 10 flower names. Show the position of 5th flower in the list.Update the flower name to “daisy”.

flower=['rose','lily','lotus','daisy','sunflower','redrose','blackrose','yellowrose','smallrose','bigrose']
print(f"5th flower is: {flower[4]}")

flower[4]='Daisy'
print(f"Updated list is:{flower}")
# Out:
# 5th flower is: sunflower
# Updated list is:['rose', 'lily', 'lotus', 'daisy', 'Daisy', 'redrose', 'blackrose', 'yellowrose', 'smallrose', 'bigrose']

# %%
#Problem_03
#The input file contains 3 values of floating points with one digit after the decimal point.Print the average of them.Output will show 2 digits after the point.

number=list(map(float,input("Enter 3 Numbers:").split()))

ave= sum(number)% len(number)
print(f"The average value is: {ave:.2f}")
# Out:
# Enter 3 Numbers: 4.456 5.345 6.546
# The average value is: 1.35

# %%
#Problem_04
'''The formula to calculate the area of a circumference is defined as A = π . R2.Considering to this problem that π = 3.14159:
The input contains a value of floating point, that is the variable R.Calculate the area
using the formula.Output will show 5 digits after the point'''

r=int(input("Enter the value of R:"))
pi=3.14159
a=pi * r ** 2
print(f"The Area is:{a:.5f}")
# Out:
# Enter the value of R: 5
# The Area is:78.53975
